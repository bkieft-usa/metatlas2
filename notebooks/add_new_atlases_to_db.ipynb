# %%
import sys
import pandas as pd
import logging

pd.options.display.max_colwidth = 600

sys.path.append('/global/homes/b/bkieft/metatlas2/metatlas2')
import workflow_objects as wfo
import load_tools as ldt
import logging_config as lcf

# %%
# Initiate logging
log_level = logging.INFO
lcf.setup_logging(log_level=log_level)
logger = lcf.get_logger('create_new_atlas', log_level=log_level)

# %%
# Load configuration files
ATLAS_CONFIG = ldt.load_atlas_config("/global/homes/b/bkieft/metatlas2/configs/create_atlases.yaml")
# Out:
# 2026-02-26 14:48:47 | metatlas2.load_tools | INFO | Loaded atlas configuration from /global/homes/b/bkieft/metatlas2/configs/create_atlases.yaml

# %%
# Add new atlas to main database
wfo.add_atlases_to_db(ATLAS_CONFIG)
# Out:
# 2026-02-26 14:48:47 | metatlas2.load_tools | INFO | Loaded 20 atlas entries from /pscratch/sd/b/bkieft/metatlas_lite_data/atlas_tables/HILICZ/HILICZ_QC_POS.tsv
# 2026-02-26 14:48:49 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ QC Atlas Positive (UID: atl-ref-qc-hilicz-pos-eeadc38364104e1e98c30f5ae0051d8d) with 20 compounds...
# 2026-02-26 14:48:49 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-02-26 14:48:49 | metatlas2.database_interact | INFO | Saving atlas Default HILICZ QC Atlas Positive to database at /pscratch/sd/b/bkieft/metatlas_lite_data/databases/metatlas.duckdb...
# 2026-02-26 14:48:49 | metatlas2.database_interact | INFO | All compounds verified to exist in the main database.
# 2026-02-26 14:48:49 | metatlas2.database_interact | INFO | Saved atlas Default HILICZ QC Atlas Positive to database with UID atl-ref-qc-hilicz-pos-eeadc38364104e1e98c30f5ae0051d8d, chromatography HILICZ, polarity POS, and analysis type QC
# 2026-02-26 14:48:49 | metatlas2.database_interact | INFO |   References created: 20
# 2026-02-26 14:48:49 | metatlas2.database_interact | INFO |   References reused: 0
# 2026-02-26 14:48:49 | metatlas2.database_interact | INFO |   Total associations: 20
# 2026-02-26 14:48:49 | metatlas2.workflow_objects | INFO | Successfully created atlas: Default HILICZ QC Atlas Positive
# 2026-02-26 14:48:49 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ QC Atlas Positive (UID: atl-ref-qc-hilicz-pos-eeadc38364104e1e98c30f5ae0051d8d) with 20 compounds...
# 2026-02-26 14:48:49 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-02-26 14:48:49 | metatlas2.load_tools | INFO | Loaded 65 atlas entries from /pscratch/sd/b/bkieft/metatlas_lite_data/atlas_tables/HILICZ/HILICZ_ISTD_POS.tsv
# 2026-02-26 14:48:53 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ ISTD Atlas Positive (UID: atl-ref-istd-hilicz-pos-57e133f3430043ebb3290774bbafdb21) with 65 compounds...
# 2026-02-26 14:48:53 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-02-26 14:48:53 | metatlas2.database_interact | INFO | Saving atlas Default HILICZ ISTD Atlas Positive to database at /pscratch/sd/b/bkieft/metatlas_lite_data/databases/metatlas.duckdb...
# 2026-02-26 14:48:53 | metatlas2.database_interact | INFO | All compounds verified to exist in the main database.
# 2026-02-26 14:48:54 | metatlas2.database_interact | INFO | Saved atlas Default HILICZ ISTD Atlas Positive to database with UID atl-ref-istd-hilicz-pos-57e133f3430043ebb3290774bbafdb21, chromatography HILICZ, polarity POS, and analysis type ISTD
# 2026-02-26 14:48:54 | metatlas2.database_interact | INFO |   References created: 45
# 2026-02-26 14:48:54 | metatlas2.database_interact | INFO |   References reused: 20
# 2026-02-26 14:48:54 | metatlas2.database_interact | INFO |   Total associations: 65
# 2026-02-26 14:48:54 | metatlas2.workflow_objects | INFO | Successfully created atlas: Default HILICZ ISTD Atlas Positive
# 2026-02-26 14:48:54 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ ISTD Atlas Positive (UID: atl-ref-istd-hilicz-pos-57e133f3430043ebb3290774bbafdb21) with 65 compounds...
# 2026-02-26 14:48:54 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-02-26 14:48:54 | metatlas2.load_tools | INFO | Loaded 373 atlas entries from /pscratch/sd/b/bkieft/metatlas_lite_data/atlas_tables/HILICZ/HILICZ_EMA_POS.tsv
# 2026-02-26 14:49:19 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ EMA Atlas Positive (UID: atl-ref-ema-hilicz-pos-1ce2d29e31c74c39afc49a1fe1501c6c) with 333 compounds...
# 2026-02-26 14:49:19 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-02-26 14:49:19 | metatlas2.database_interact | INFO | Saving atlas Default HILICZ EMA Atlas Positive to database at /pscratch/sd/b/bkieft/metatlas_lite_data/databases/metatlas.duckdb...
# 2026-02-26 14:49:20 | metatlas2.database_interact | INFO | All compounds verified to exist in the main database.
# 2026-02-26 14:49:22 | metatlas2.database_interact | INFO | Saved atlas Default HILICZ EMA Atlas Positive to database with UID atl-ref-ema-hilicz-pos-1ce2d29e31c74c39afc49a1fe1501c6c, chromatography HILICZ, polarity POS, and analysis type EMA
# 2026-02-26 14:49:22 | metatlas2.database_interact | INFO |   References created: 333
# 2026-02-26 14:49:22 | metatlas2.database_interact | INFO |   References reused: 0
# 2026-02-26 14:49:22 | metatlas2.database_interact | INFO |   Total associations: 333
# 2026-02-26 14:49:22 | metatlas2.workflow_objects | INFO | Successfully created atlas: Default HILICZ EMA Atlas Positive
# 2026-02-26 14:49:22 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ EMA Atlas Positive (UID: atl-ref-ema-hilicz-pos-1ce2d29e31c74c39afc49a1fe1501c6c) with 333 compounds...
# 2026-02-26 14:49:22 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-02-26 14:49:22 | metatlas2.workflow_objects | INFO | Atlas creation summary:
# 2026-02-26 14:49:22 | metatlas2.workflow_objects | INFO | Atlas: Default HILICZ QC Atlas Positive (UID: atl-ref-qc-hilicz-pos-eeadc38364104e1e98c30f5ae0051d8d) - 20 compounds
# 2026-02-26 14:49:22 | metatlas2.workflow_objects | INFO | Atlas: Default HILICZ ISTD Atlas Positive (UID: atl-ref-istd-hilicz-pos-57e133f3430043ebb3290774bbafdb21) - 65 compounds
# 2026-02-26 14:49:22 | metatlas2.workflow_objects | INFO | Atlas: Default HILICZ EMA Atlas Positive (UID: atl-ref-ema-hilicz-pos-1ce2d29e31c74c39afc49a1fe1501c6c) - 333 compounds
