# %%
import sys
sys.path.append('/global/homes/b/bkieft/metatlas2/metatlas2')
import targeted_gui as tgi
# Out:
# /global/homes/b/bkieft/.conda/envs/metatlas_lite/lib/python3.11/site-packages/seaborn/_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.5)
#   from scipy.stats import gaussian_kde

# %%
# Create database-connected GUI
gui, db_info = tgi.create_gui_from_database(
    project_db_path="/pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402.duckdb",
    rt_alignment_number=1,
    analysis_number=0,
)

display(gui)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Create database-connected GUI
# ----> 2 gui, db_info = tgi.create_gui_from_database(
#       3     project_db_path="/pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402.duckdb",
#       4     rt_alignment_number=1,
#       5     analysis_number=0,
#       6 )
#       8 display(gui)
#
# File ~/metatlas2/metatlas2/targeted_gui.py:55, in create_gui_from_database(project_db_path, rt_alignment_number, analysis_number)
#      49 """
#      50 Create GUI by loading compound data directly from project database.
#      51 Only loads metadata initially - full data loaded on-demand per compound.
#      52 """
#      53 with dbi.get_db_connection(project_db_path) as conn:
# ...
