# %%
import sys
import pandas as pd
pd.options.display.max_colwidth = 600

sys.path.append('/global/homes/b/bkieft/metatlas2/metatlas2')
import logging_config as lcf
import logging
import workflow_objects as wfo
import load_tools as ldt

# %%
# Set up logging with level
log_level = logging.INFO
lcf.setup_logging(log_level=log_level)
logger = lcf.get_logger('auto_identification', log_level=log_level)

# %%
# Load configuration files
ANALYSIS_CONFIG = ldt.load_metatlas2_config("/global/homes/b/bkieft/metatlas2/configs/analysis.yaml")
# Out:
# 2026-02-26 15:30:10 | metatlas2.load_tools | INFO | Loaded metatlas2 configuration from /global/homes/b/bkieft/metatlas2/configs/analysis.yaml

# %%
# Set up analysis parameters
PROJECT_NAME = "20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402"
ANALYSIS_ATLAS = "atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919"
RT_ALIGN_NUM = 0
ANALYSIS_NUM = 0

# %%
# Auto Identifications
wfo.run_auto_identification(
    config=ANALYSIS_CONFIG,
    project_name=PROJECT_NAME,
    rt_alignment_number=RT_ALIGN_NUM,
    analysis_number=ANALYSIS_NUM,
    analysis_atlas=ANALYSIS_ATLAS
)
# Out:
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Setting up AutoIdentification object for RT alignment number 0, analysis number 0 for project 20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402...
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Setting up workflow paths...
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Checking for existing Auto Identification results within RT Alignment number 0 and analysis number 0...
# 2026-02-26 15:30:10 | metatlas2.database_interact | INFO | No existing AutoIdentification results found for RT alignment number 0 and analysis number 0. Proceeding.
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Retrieving all LCMS runs for project...
# 2026-02-26 15:30:10 | metatlas2.database_interact | INFO | Retrieved 34 LC/MS run files from database with filters: file_types=None, chromatography=None, polarity=None, format=parquet
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Loading atlas with UID atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919 from database...
# 2026-02-26 15:30:10 | metatlas2.database_interact | INFO | Attached main database for compound metadata
# 2026-02-26 15:30:10 | metatlas2.database_interact | INFO | Retrieved 65 compounds for atlas atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919 (Default HILICZ ISTD Atlas Positive (RT aligned))
#                                                   atlas_uid  \
# 0  atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919
# 1  atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919
# 2  atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919
# 3  atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919
# 4  atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919
#
#                                         atlas_name  \
# 0  Default HILICZ ISTD Atlas Positive (RT aligned)
# 1  Default HILICZ ISTD Atlas Positive (RT aligned)
# 2  Default HILICZ ISTD Atlas Positive (RT aligned)
# 3  Default HILICZ ISTD Atlas Positive (RT aligned)
# 4  Default HILICZ ISTD Atlas Positive (RT aligned)
#
#                                           atlas_description chromatography  \
# 0  RT-aligned version of Default HILICZ ISTD Atlas Positive         HILICZ
# 1  RT-aligned version of Default HILICZ ISTD Atlas Positive         HILICZ
# 2  RT-aligned version of Default HILICZ ISTD Atlas Positive         HILICZ
# 3  RT-aligned version of Default HILICZ ISTD Atlas Positive         HILICZ
# 4  RT-aligned version of Default HILICZ ISTD Atlas Positive         HILICZ
#
#   polarity analysis_type  atlas_type                          compound_uid  \
# 0      POS          ISTD  RT-ALIGNED  cmp-11a0187b0f52452d9b60b60e9495e950
# 1      POS          ISTD  RT-ALIGNED  cmp-6f1914c6411c458f912e677857e2c603
# 2      POS          ISTD  RT-ALIGNED  cmp-8f26a0c30cb44ac0a09de8cf88c01388
# 3      POS          ISTD  RT-ALIGNED  cmp-5a591e980afe4edc8abe9776797ec1c4
# 4      POS          ISTD  RT-ALIGNED  cmp-fcb50631a9a74d9fba4c17a905754644
#
#               compound_name                    inchi_key  \
# 0         ABMBA (unlabeled)  LCMZECCEEOQWLQ-UHFFFAOYSA-N
# 1    nicotinamide (U - 13C)  DFPAKSUCGFBDDF-IDEBNGHGSA-N
# 2  nicotinamide (unlabeled)  DFPAKSUCGFBDDF-UHFFFAOYSA-N
# 3    thymine (U - 13C, 15N)  RWQNBRDOKXIBIV-BNUYUSEDSA-N
# 4       thymine (unlabeled)  RWQNBRDOKXIBIV-UHFFFAOYSA-N
#
#                                                                                       inchi  \
# 0                 InChI=1S/C8H8BrNO2/c1-4-2-5(8(11)12)7(10)6(9)3-4/h2-3H,10H2,1H3,(H,11,12)
# 1             InChI=1S/C6H6N2O/c7-6(9)5-2-1-3-8-4-5/h1-4H,(H2,7,9)/i1+1,2+1,3+1,4+1,5+1,6+1
# 2                                      InChI=1S/C6H6N2O/c7-6(9)5-2-1-3-8-4-5/h1-4H,(H2,7,9)
# 3  InChI=1S/C5H6N2O2/c1-3-2-6-5(9)7-4(3)8/h2H,1H3,(H2,6,7,8,9)/i1+1,2+1,3+1,4+1,5+1,6+1,7+1
# 4                               InChI=1S/C5H6N2O2/c1-3-2-6-5(9)7-4(3)8/h2H,1H3,(H2,6,7,8,9)
#
#    adduct          mz   rt_peak    rt_min    rt_max  mz_tolerance  \
# 0  [M+H]+  229.981094  1.231498  0.974626  1.489877           5.0
# 1  [M+H]+  129.075424  1.276848  1.019712  1.535492           5.0
# 2  [M+H]+  123.055290  1.276848  1.019712  1.535492           5.0
# 3  [M+H]+  134.061035  1.370339  1.112657  1.629530           5.0
# 4  [M+H]+  127.050201  1.370339  1.112657  1.629530           5.0
#
#                                    mz_rt_uid  rt_alignment_applied  \
# 0  mzrt-exp-199681fa9d15401da743986bb748b845                  True
# 1  mzrt-exp-6c2976b50e644bc9a24cd6f9c98923b6                  True
# 2  mzrt-exp-cd17b3cd877c403ab510d6fba929d439                  True
# 3  mzrt-exp-b8a353c5ff734e7ab80ba144702a296f                  True
# 4  mzrt-exp-036101a76a8944ca8eb73a14c40037cc                  True
#
#    manual_curation_applied
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ ISTD Atlas Positive (RT aligned) (UID: atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919) with 65 compounds...
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Loading workflow parameters for targeted analysis from config...
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Finding LCMSRuns matching criteria for auto-identification...
# 2026-02-26 15:30:10 | metatlas2.lcmsruns_tools | INFO | Filtering 34 LCMS runs with parameters: file_type=['experimental', 'istd', 'exctrl', 'refstd'], file_format=parquet, chromatography=HILIC, polarity=positive...
# 2026-02-26 15:30:10 | metatlas2.lcmsruns_tools | INFO | Filtered to 13 out of 34 total files.
# 2026-02-26 15:30:10 | metatlas2.workflow_objects | INFO | Passing Atlas and LCMSRuns to data extractor...
# 2026-02-26 15:30:10 | metatlas2.extract_data_from_parquet | INFO | Starting data extraction based on atl-rta-istd-hilicz-pos-2629de26a08b4af8b3cac8fadf695919 (Default HILICZ ISTD Atlas Positive (RT aligned)) for stage 'auto_identification' from 13 LCMS runs...
# 2026-02-26 15:30:10 | metatlas2.extract_data_from_parquet | INFO | Initiating an experimental data object to hold results during analysis...
# 2026-02-26 15:30:10 | metatlas2.extract_data_from_parquet | INFO | Starting data extraction for 65 compounds from 13 project files...
# 2026-02-26 15:30:10 | metatlas2.extract_data_from_parquet | INFO | Using ppm_tolerance=5.0 and extra_time=1.0 for data extraction.
# 2026-02-26 15:30:10 | metatlas2.extract_data_from_parquet | INFO | Using parallel processing with 8 workers...
# Extracting data from parquet files:   0%|          | 0/13 [00:00<?, ?it/s]
# 2026-02-26 15:30:13 | metatlas2.workflow_objects | INFO | Passing ExperimentalData to MS2 hit finder...
# 2026-02-26 15:30:13 | metatlas2.load_tools | INFO | Loading reference spectra from /pscratch/sd/b/bkieft/metatlas_lite_data/databases/msms_refs/msms_refs_no_inosine15n.tab...
# 2026-02-26 15:30:13 | metatlas2.load_tools | INFO |     Number of total references: 1584
# 2026-02-26 15:30:13 | metatlas2.load_tools | INFO |     Number of unique InChI keys: 64
# 2026-02-26 15:30:13 | metatlas2.ms2_hit_detection | INFO | Finding MS2 hits using reference database with 1584 entries...
# 2026-02-26 15:30:13 | metatlas2.ms2_hit_detection | INFO | Prepared hit detection input for 63 files with MS2 data
# 2026-02-26 15:30:13 | metatlas2.ms2_hit_detection | INFO | Using parallel processing with 8 workers for hit detection...
# Finding MS2 hits:   0%|          | 0/63 [00:00<?, ?it/s]
# 2026-02-26 15:30:16 | metatlas2.ms2_hit_detection | INFO | Hit detection complete: 63 compounds with reference hits and 4392 total hits
# 2026-02-26 15:30:16 | metatlas2.workflow_objects | INFO | Passing ExperimentalData and Atlas to ManualCuration creator...
# Processing atlas compounds:   0%|          | 0/65 [00:00<?, ?compound/s]
# 2026-02-26 15:30:21 | metatlas2.workflow_objects | INFO | Passing finalized AutoIdentification object to database saver...
# 2026-02-26 15:30:21 | metatlas2.database_interact | INFO | Preparing AutoIdentification results for database save...
# 2026-02-26 15:30:21 | metatlas2.database_interact | INFO | Processing manual curation entries...
# Compounds:   0%|          | 0/65 [00:00<?, ?it/s]
# 2026-02-26 15:30:21 | metatlas2.database_interact | INFO | Processing MS1 data entries...
# MS1 data files:   0%|          | 0/845 [00:00<?, ?it/s]
# 2026-02-26 15:30:23 | metatlas2.database_interact | INFO | Processing MS2 data entries...
# MS2 data scans:   0%|          | 0/845 [00:00<?, ?it/s]
# 2026-02-26 15:30:23 | metatlas2.database_interact | INFO | Processing MS2 hit entries...
# MS2 hit entries:   0%|          | 0/63 [00:00<?, ?it/s]
# 2026-02-26 15:30:24 | metatlas2.database_interact | INFO | Checking for identical ManualCuration records before database insert...
# 2026-02-26 15:30:24 | metatlas2.database_interact | INFO | Performing bulk database inserts...
# 2026-02-26 15:30:24 | metatlas2.database_interact | INFO | Inserting 65 compound metadata records...
# 2026-02-26 15:30:24 | metatlas2.database_interact | INFO | Inserting 4392 MS2 hits records...
# 2026-02-26 15:30:41 | metatlas2.database_interact | INFO | Inserting 354 MS1 raw data records...
# 2026-02-26 15:30:41 | metatlas2.database_interact | INFO | Inserting 298 MS2 raw data records...
# 2026-02-26 15:30:42 | metatlas2.database_interact | INFO | Database save complete.
# 2026-02-26 15:30:42 | metatlas2.workflow_objects | INFO | Passing AutoIdentification object to summary generator...
#                       inchi_key  adduct  MS1 datapoints  MS2 datapoints  \
# 0   LCMZECCEEOQWLQ-UHFFFAOYSA-N  [M+H]+             740             199
# 1   DFPAKSUCGFBDDF-IDEBNGHGSA-N  [M+H]+             194               0
# 2   DFPAKSUCGFBDDF-UHFFFAOYSA-N  [M+H]+             979               0
# 3   RWQNBRDOKXIBIV-BNUYUSEDSA-N  [M+H]+              55               0
# 4   RWQNBRDOKXIBIV-UHFFFAOYSA-N  [M+H]+              42               0
# ..                          ...     ...             ...             ...
# 60  LEVWYRKDKASIDU-IMJSIDKUSA-N  [M+H]+               0               0
# 61  ODKSFYDXXFIFQN-GZYYCROJSA-N  [M+H]+            1354             253
# 62  ODKSFYDXXFIFQN-BYPYZUCNSA-N  [M+H]+             133               9
# 63  KDXKERNSBIXSRK-JMKXWGMHSA-N  [M+H]+             318             131
# 64  KDXKERNSBIXSRK-YFKPBYRVSA-N  [M+H]+              28               0
#
#     MS2 hits
# 0        150
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 60         0
# 61       154
# 62       118
# 63        77
# 64         0
#
# [65 rows x 5 columns]
