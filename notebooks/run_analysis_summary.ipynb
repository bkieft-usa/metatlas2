# %%
import sys
import pandas as pd
pd.options.display.max_colwidth = 600

sys.path.append('/global/homes/b/bkieft/metatlas2/metatlas2')
import logging_config as lcf
import logging
import load_tools as ldt
import run_workflows as rwf

# %%
# Set up logging with level
log_level = logging.INFO
lcf.setup_logging(log_level=log_level)
logger = lcf.get_logger('analysis_gui', log_level=log_level)

# %%
# Load configuration files
ANALYSIS_CONFIG = ldt.load_metatlas2_config("/global/homes/b/bkieft/metatlas2/configs/analysis.yaml")
# Out:
# 2026-03-08 14:33:26 | metatlas2.load_tools | INFO | Loaded metatlas2 configuration from /global/homes/b/bkieft/metatlas2/configs/analysis.yaml

# %%
# Set up analysis parameters
PROJECT_NAME = "20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402"
ANALYSIS_ATLAS = "atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494"
RT_ALIGN_NUM = 0
ANALYSIS_NUM = 1

# %%
rwf.run_analysis_summary(
    config=ANALYSIS_CONFIG, 
    project_name=PROJECT_NAME, 
    rt_alignment_number=RT_ALIGN_NUM, 
    analysis_number=ANALYSIS_NUM,
    analysis_atlas=ANALYSIS_ATLAS,
    overwrite=True
)
# Out:
# 2026-03-08 14:36:26 | metatlas2.workflow_objects | INFO | Setting up AnalysisSummary object for RT alignment number 0, analysis number 1 for project 20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402...
# 2026-03-08 14:36:26 | metatlas2.workflow_objects | INFO | Setting up workflow paths...
# 2026-03-08 14:36:26 | metatlas2.workflow_objects | INFO | AnalysisSummary.load_data: loading RT alignment 0, analysis 1…
# 2026-03-08 14:36:27 | metatlas2.workflow_objects | INFO | load_data complete: 59 compounds, 354 MS1 rows, 298 MS2 raw rows, 4392 MS2 hit rows.
# 2026-03-08 14:36:27 | metatlas2.workflow_objects | INFO | Loading atlas with UID atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494 from database...
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Attached main database for compound metadata
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Retrieved 59 compounds for atlas atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494 (Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification))
#                                                   atlas_uid  \
# 0  atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494
# 1  atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494
# 2  atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494
# 3  atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494
# 4  atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494
#
#                                                                           atlas_name  \
# 0  Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification)
# 1  Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification)
# 2  Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification)
# 3  Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification)
# 4  Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification)
#
#                                                                                                   atlas_description  \
# 0  Default internal standard compounds used for checking performance (post-rt-alignment) (post-auto-identification)
# 1  Default internal standard compounds used for checking performance (post-rt-alignment) (post-auto-identification)
# 2  Default internal standard compounds used for checking performance (post-rt-alignment) (post-auto-identification)
# 3  Default internal standard compounds used for checking performance (post-rt-alignment) (post-auto-identification)
# 4  Default internal standard compounds used for checking performance (post-rt-alignment) (post-auto-identification)
#
#   chromatography polarity analysis_type  atlas_type  \
# 0         HILICZ      POS          ISTD  RT-ALIGNED
# 1         HILICZ      POS          ISTD  RT-ALIGNED
# 2         HILICZ      POS          ISTD  RT-ALIGNED
# 3         HILICZ      POS          ISTD  RT-ALIGNED
# 4         HILICZ      POS          ISTD  RT-ALIGNED
#
#                            compound_uid             compound_name  \
# 0  cmp-3494f83b522f43d99a7e77dc4fe44060         ABMBA (unlabeled)
# 1  cmp-4f3491994fef473e8fe24c12c6292b8d    nicotinamide (U - 13C)
# 2  cmp-a8843d8ac3854021a3508f4ed3492f61  nicotinamide (unlabeled)
# 3  cmp-d2009e7a69194966b78a7f40f44509a7    thymine (U - 13C, 15N)
# 4  cmp-7936c41774a440ddb9cb1e08c59c874f       thymine (unlabeled)
#
#                      inchi_key  \
# 0  LCMZECCEEOQWLQ-UHFFFAOYSA-N
# 1  DFPAKSUCGFBDDF-IDEBNGHGSA-N
# 2  DFPAKSUCGFBDDF-UHFFFAOYSA-N
# 3  RWQNBRDOKXIBIV-BNUYUSEDSA-N
# 4  RWQNBRDOKXIBIV-UHFFFAOYSA-N
#
#                                                                                       inchi  \
# 0                 InChI=1S/C8H8BrNO2/c1-4-2-5(8(11)12)7(10)6(9)3-4/h2-3H,10H2,1H3,(H,11,12)
# 1             InChI=1S/C6H6N2O/c7-6(9)5-2-1-3-8-4-5/h1-4H,(H2,7,9)/i1+1,2+1,3+1,4+1,5+1,6+1
# 2                                      InChI=1S/C6H6N2O/c7-6(9)5-2-1-3-8-4-5/h1-4H,(H2,7,9)
# 3  InChI=1S/C5H6N2O2/c1-3-2-6-5(9)7-4(3)8/h2H,1H3,(H2,6,7,8,9)/i1+1,2+1,3+1,4+1,5+1,6+1,7+1
# 4                               InChI=1S/C5H6N2O2/c1-3-2-6-5(9)7-4(3)8/h2H,1H3,(H2,6,7,8,9)
#
#    adduct          mz   rt_peak    rt_min    rt_max  mz_tolerance  \
# 0  [M+H]+  229.981094  1.231498  0.974626  1.489877           5.0
# 1  [M+H]+  129.075424  1.276848  1.019712  1.535492           5.0
# 2  [M+H]+  123.055290  1.276848  1.019712  1.535492           5.0
# 3  [M+H]+  134.061035  1.370339  1.112657  1.629530           5.0
# 4  [M+H]+  127.050201  1.370339  1.112657  1.629530           5.0
#
#                                    mz_rt_uid ms1_notes ms2_notes
# 0  mzrt-exp-514f713de6ae490b8acbba91382b6620       nan       nan
# 1  mzrt-exp-159d518f0a62463c86bc7be100c8a215       nan       nan
# 2  mzrt-exp-41440a80c9dd4cf6be028d297a5efd62       nan       nan
# 3  mzrt-exp-0a8250fc282f47adb7d7eed997f28153       nan       nan
# 4  mzrt-exp-480286d8787b4a298cdbca1599dc1040       nan       nan
# 2026-03-08 14:36:27 | metatlas2.workflow_objects | INFO | Validating atlas Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification) (UID: atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494) with 59 compounds...
# 2026-03-08 14:36:27 | metatlas2.workflow_objects | INFO | Atlas passed validation!
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Removing compound cmp-3494f83b522f43d99a7e77dc4fe44060 (LCMZECCEEOQWLQ-UHFFFAOYSA-N / [M+H]+) from atlas because ms1_notes contains 'remove'.
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Removing compound cmp-a8843d8ac3854021a3508f4ed3492f61 (DFPAKSUCGFBDDF-UHFFFAOYSA-N / [M+H]+) from atlas because ms1_notes contains 'remove'.
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Removing compound cmp-d2009e7a69194966b78a7f40f44509a7 (RWQNBRDOKXIBIV-BNUYUSEDSA-N / [M+H]+) from atlas because ms1_notes contains 'remove'.
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Saving atlas Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification) (post-manual-curation) to database at /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402.duckdb...
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | All compounds verified to exist in the main database.
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Saved atlas Default HILICZ ISTD Atlas Positive (post-rt-alignment) (post-auto-identification) (post-manual-curation) to database with UID atl-aid-istd-hilicz-pos-b2fc70d977e54184bf45a05ce065ba98, chromatography HILICZ, polarity POS, and analysis type ISTD
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO |   References created: 0
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO |   References reused: 56
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO |   Total associations: 56
# 2026-03-08 14:36:27 | metatlas2.database_interact | INFO | Created and saved post-curation atlas atl-aid-istd-hilicz-pos-b2fc70d977e54184bf45a05ce065ba98 (from source atlas atl-aid-istd-hilicz-pos-7d80a2dbd7b14f708137e83e48c0d494) with (56 compounds).
# 2026-03-08 14:36:27 | metatlas2.analysis_summary | INFO | Making Identification figures…
# 2026-03-08 14:36:27 | metatlas2.analysis_summary | INFO | Exporting identification figures to /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402_RTA0_TGA1/identification_figures
# 2026-03-08 14:36:27 | metatlas2.analysis_summary | INFO | Plotting 59 compounds across 8 files.
# Generating ID figures:   0%|          | 0/59 [00:00<?, ?it/s]
# 2026-03-08 14:37:19 | metatlas2.analysis_summary | INFO | Identification figure export complete → /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402_RTA0_TGA1/identification_figures
# 2026-03-08 14:37:19 | metatlas2.analysis_summary | INFO | Making EIC thumbnails…
# 2026-03-08 14:37:19 | metatlas2.analysis_summary | INFO | Generating EIC thumbnail PDFs for 59 compounds…
# Generating EIC thumbnails:   0%|          | 0/59 [00:00<?, ?it/s]
# 2026-03-08 14:39:20 | metatlas2.analysis_summary | INFO | EIC thumbnail PDFs complete.
#   Shared y:      /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402_RTA0_TGA1/eic_thumbnails_shared_y
#   Independent y: /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402_RTA0_TGA1/eic_thumbnails_independent_y
# 2026-03-08 14:39:20 | metatlas2.analysis_summary | INFO | Making Stats table…
# 2026-03-08 14:39:20 | metatlas2.analysis_summary | INFO | Processing 59 compounds…
# Making stats table:   0%|          | 0/59 [00:00<?, ?it/s]
# 2026-03-08 14:39:20 | metatlas2.analysis_summary | INFO | Assembled stats table with 59 rows.
# 2026-03-08 14:39:20 | metatlas2.analysis_summary | INFO | Exported stats table to /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402_RTA0_TGA1/Draft_Final_Identifications.xlsx
# 2026-03-08 14:39:20 | metatlas2.analysis_summary | INFO | Making Boxplots…
# 2026-03-08 14:39:20 | metatlas2.analysis_summary | INFO | Writing boxplot_peak_height_linear.pdf…
# 2026-03-08 14:39:30 | metatlas2.analysis_summary | INFO | Writing boxplot_peak_height_log.pdf…
# 2026-03-08 14:39:39 | metatlas2.analysis_summary | INFO | Writing boxplot_rt_peak_linear.pdf…
# 2026-03-08 14:39:48 | metatlas2.analysis_summary | INFO | Writing boxplot_rt_peak_log.pdf…
# 2026-03-08 14:39:58 | metatlas2.analysis_summary | INFO | Writing boxplot_mz_centroid_linear.pdf…
# 2026-03-08 14:40:08 | metatlas2.analysis_summary | INFO | Writing boxplot_mz_centroid_log.pdf…
# 2026-03-08 14:40:17 | metatlas2.analysis_summary | INFO | Boxplot PDFs complete → /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402_RTA0_TGA1
# 2026-03-08 14:40:17 | metatlas2.analysis_summary | INFO | Making Manual curation CSV…
# 2026-03-08 14:40:17 | metatlas2.analysis_summary | INFO | Exported manual curation CSV to /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402_RTA0_TGA1/manual_curation.csv
# 2026-03-08 14:40:17 | metatlas2.analysis_summary | INFO | run_all_summaries: all outputs complete.
