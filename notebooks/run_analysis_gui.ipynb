# %%
import sys
import pandas as pd
pd.options.display.max_colwidth = 900

sys.path.append('/Users/BKieft/Metabolomics/metatlas2/metatlas2')
import logging_config as lcf
import logging
import workflow_objects as wfo
import load_tools as ldt
import analysis_gui as agu

# %%
# Set up logging with level
log_level = logging.INFO
lcf.setup_logging(log_level=log_level)
logger = lcf.get_logger('analysis_gui', log_level=log_level)

# %%
# Load configuration files
ANALYSIS_CONFIG = ldt.load_metatlas2_config("/Users/BKieft/Metabolomics/metatlas2/configs/analysis.yaml")
# Out:
# 2026-02-25 14:07:49 | metatlas2.load_tools | INFO | Loaded metatlas2 configuration from /Users/BKieft/Metabolomics/metatlas2/configs/analysis.yaml

# %%
# Set up analysis parameters
PROJECT_NAME = "20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402"
RT_ALIGN_NUM = 0
ANALYSIS_NUM = 0

# %%
# Set up analysis GUI object

analysis_gui_obj = wfo.AnalysisGUI()

analysis_gui_obj.setup(
    config=ANALYSIS_CONFIG, 
    project_name=PROJECT_NAME, 
    rt_alignment_number=RT_ALIGN_NUM, 
    analysis_number=ANALYSIS_NUM
)

analysis_gui = agu.run_analysis_gui(
    analysis_gui_obj
)
# Out:
# 2026-02-25 14:07:49 | metatlas2.workflow_objects | INFO | Setting up AnalysisGUI object for RT alignment number 0, analysis number 0 for project 20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402...
# 2026-02-25 14:07:49 | metatlas2.workflow_objects | INFO | Setting up workflow paths...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 12
#       3 analysis_gui_obj = wfo.AnalysisGUI()
#       5 analysis_gui_obj.setup(
#       6     config=ANALYSIS_CONFIG,
#       7     project_name=PROJECT_NAME,
#       8     rt_alignment_number=RT_ALIGN_NUM,
#       9     analysis_number=ANALYSIS_NUM
#      10 )
# ---> 12 analysis_gui = agu.run_analysis_gui(
#      13     analysis_gui_obj
#      14 )
#
# File ~/Metabolomics/metatlas2/metatlas2/analysis_gui.py:675, in run_analysis_gui(analysis_gui_obj)
#     664 container = widgets.VBox([
#     665     nav_box,
#     666     analyst_notes_box,
#    (...)
#     671     identification_notes_display
#     672 ], layout=widgets.Layout(width='100%', align_items='flex-start', height='fit-content'))
#     674 # --- 9. Initialize ---
# --> 675 full_update()
#     676 logger.info(f"Manual curation GUI created with {len(compound_list)} compounds")
#     677 return container
#
# File ~/Metabolomics/metatlas2/metatlas2/analysis_gui.py:634, in run_analysis_gui.<locals>.full_update()
#     631             updating[0] = temp_updating
#     633     # Update plot
# --> 634     create_plot_only(initial_render=True)
#     635 finally:
#     636     updating[0] = False
#
# File ~/Metabolomics/metatlas2/metatlas2/analysis_gui.py:504, in run_analysis_gui.<locals>.create_plot_only(initial_render)
#     501 ms2_counter_label.value = f"MS2 Scan {idx+1} of {total_scans}" if total_scans > 0 else "No MS2 data"
#     503 # Plot MS2 spectrum for selected scan
# --> 504 ms2_title = _create_plot_titles(
#     505     manual_curation_entry=manual_curation_entry,
#     506     ms_level=2,
#     507     ms2_data=scan
#     508 )
#     509 if scan is not None:
#     510     # Use fragment_colors if present, else default to red
#     511     fragment_colors = None
#
# File ~/Metabolomics/metatlas2/metatlas2/analysis_gui.py:401, in run_analysis_gui.<locals>._create_plot_titles(manual_curation_entry, ms_level, ms1_data, ms2_data)
#     396     else:
#     397         file_name = "_".join(os.path.basename(ms2_data['file_path']).split('.')[0].split('_')[10:])
#     398         title = (
#     399             f"{manual_curation_entry['compound_name']} | {manual_curation_entry['adduct']} | {manual_curation_entry['inchi_key']}\n"
#     400             f"File: {file_name}\n"
# --> 401             f"Score: {ms2_data['score']:.4f} | Scan RT: {ms2_data['rt']:.2f} | Ref Scale: {scale_factor:.2f}\n"
#     402             f"Precursor m/z: {ms2_data['precursor_MZ']:.4f} | Reference m/z: {ms2_data['mz_theoretical']:.4f}\n"
#     403             f"Measured m/z: {ms2_data['mz_measured']:.4f} | m/z Diff: {ms2_data['ppm_error']:.2f}"
#     404         )
#     406 return title
#
# NameError: name 'scale_factor' is not defined

# %%
display(analysis_gui)
