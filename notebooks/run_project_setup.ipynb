# %%
import sys
import pandas as pd
pd.options.display.max_colwidth = 600

sys.path.append('/global/homes/b/bkieft/metatlas2/metatlas2')
import logging_config as lcf
import logging
import workflow_objects as wfo
import load_tools as ldt

# %%
# Set up logging with level
log_level = logging.INFO
lcf.setup_logging(log_level=log_level)
logger = lcf.get_logger('project_setup', log_level=log_level)

# %%
# Load configuration file
ANALYSIS_CONFIG = ldt.load_metatlas2_config("/global/homes/b/bkieft/metatlas2/configs/analysis.yaml")
# Out:
# 2026-02-26 15:25:13 | metatlas2.load_tools | INFO | Loaded metatlas2 configuration from /global/homes/b/bkieft/metatlas2/configs/analysis.yaml

# %%
# Set up parameters
PROJECT_NAME = "20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402"

# %%
# Setup project and database
wfo.run_project_setup(
    project_name=PROJECT_NAME,
    config=ANALYSIS_CONFIG,
    overwrite_existing=True
)
# Out:
# 2026-02-26 15:25:13 | metatlas2.workflow_objects | INFO | Setting up workflow paths for project 20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402...
# 2026-02-26 15:25:13 | metatlas2.workflow_objects | INFO | Creating project database at /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402.duckdb...
# 2026-02-26 15:25:13 | metatlas2.database_interact | WARNING | Overwriting existing project database at /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402.duckdb (overwrite=True)
# 2026-02-26 15:25:13 | metatlas2.database_interact | INFO | Deleted existing database at /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402.duckdb
# 2026-02-26 15:25:14 | metatlas2.database_interact | INFO | Project database created at /pscratch/sd/b/bkieft/metatlas_lite_data/projects/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402.duckdb
# 2026-02-26 15:25:14 | metatlas2.workflow_objects | INFO | Loading LCMS runs...
# 2026-02-26 15:25:14 | metatlas2.lcmsruns_tools | INFO | Found 34 .parquet files in /pscratch/sd/b/bkieft/metatlas_lite_data/raw_data/jgi/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402
# 2026-02-26 15:25:14 | metatlas2.lcmsruns_tools | INFO | Found 17 .raw files in /pscratch/sd/b/bkieft/metatlas_lite_data/raw_data/jgi/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402
# 2026-02-26 15:25:14 | metatlas2.lcmsruns_tools | INFO | Found 17 .mzML files in /pscratch/sd/b/bkieft/metatlas_lite_data/raw_data/jgi/20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402
# 2026-02-26 15:25:14 | metatlas2.workflow_objects | INFO | Saving LCMS runs metadata to database...
# 2026-02-26 15:25:14 | metatlas2.database_interact | INFO | Saved 68 LCMS runs to database.
# 2026-02-26 15:25:14 | metatlas2.workflow_objects | INFO | Storing LCMS runs in Project object...
