# %%
import sys
import pandas as pd
pd.options.display.max_colwidth = 600

sys.path.append('/Users/BKieft/Metabolomics/metatlas2/metatlas2')
import logging_config as lcf
import logging
import workflow_objects as wfo
import load_tools as ldt

# %%
# Set up logging with level
log_level = logging.INFO
lcf.setup_logging(log_level=log_level)
logger = lcf.get_logger('targeted_workflow', log_level=log_level)

# %%
# Load configuration files
ANALYSIS_CONFIG = ldt.load_metatlas2_config("/Users/BKieft/Metabolomics/metatlas2/configs/analysis.yaml")
# Out:
# 2026-02-23 14:42:59 | metatlas2.load_tools | INFO | Loaded metatlas2 configuration from /Users/BKieft/Metabolomics/metatlas2/configs/analysis.yaml

# %%
# Set up analysis parameters
PROJECT_NAME = "20260106_JGI_LP-AC_510770_StrigoArab_final_EXP120B_HILICZ_USHXG03402"

ANALYSIS_ATLAS = "atl-rta-istd-hilicz-pos-2f164784d4b24886aca24595835c2544"

RT_ALIGN_NUM = 0
ANALYSIS_NUM = 0

# %%
# Auto Identifications
wfo.run_auto_identification(
    config=ANALYSIS_CONFIG,
    project_name=PROJECT_NAME,
    rt_alignment_number=RT_ALIGN_NUM,
    analysis_number=ANALYSIS_NUM,
    analysis_atlas_uid=ANALYSIS_ATLAS
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Auto Identifications
# ----> 2 wfo.run_auto_identification(
#       3     config=ANALYSIS_CONFIG,
#       4     project_name=PROJECT_NAME,
#       5     rt_alignment_number=RT_ALIGN_NUM,
#       6     analysis_number=ANALYSIS_NUM,
#       7     analysis_atlas=ANALYSIS_ATLAS
#       8 )
#
# File ~/Metabolomics/metatlas2/metatlas2/workflow_objects.py:816, in run_auto_identification(config, project_name, rt_alignment_number, analysis_number, analysis_atlas)
#     806 """
#     807 Runs targeted analysis using RT-aligned atlases from database.
#     808 Can be run independently if RT alignment has been completed.
#    (...)
#     811     Dict with analysis statistics: {atlas_uid: num_identifications}
#     812 """
#     814 auto_id_obj = AutoIdentification()
# --> 816 auto_id_obj.setup(
#     817     config=config,
#     818     project_name=project_name,
#     819     rt_alignment_number=rt_alignment_number,
#     820     analysis_number=analysis_number,
#     821     analysis_atlas=analysis_atlas
#     822 )
#     824 auto_id_obj.experimental_data = pdx.extract_eic_and_ms2_from_parquet(
#     825     atlas=auto_id_obj.atlas_obj,
#     826     stage="auto_identification",
#     827     lcmsruns=auto_id_obj.autoid_lcmsruns,
#     828     workflow_params=auto_id_obj.workflow_params
#     829 )
#     831 auto_id_obj.experimental_data = mhd.find_ms2_hits(
#     832     exp_data_obj=auto_id_obj.experimental_data,
#     833     msms_refs_path=auto_id_obj.paths['msms_refs_path']
#     834 )
#
# TypeError: AutoIdentification.setup() got an unexpected keyword argument 'analysis_atlas'
